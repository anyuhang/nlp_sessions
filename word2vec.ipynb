# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %% [raw]
# print (os.getcwd())

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])
print(data[:8])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# [5239, 3084, 12, 6, 195, 2, 3137, 46]
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.335612
# Nearest to an: tombs, lanthanides, changeable, delaware, carlyle, mythologies, snell, lent,
# Nearest to called: benefits, inflationary, superset, ringers, favor, geocentric, crafty, faroes,
# Nearest to d: sorghum, partake, mimeograph, vegeta, handwriting, ragged, massey, rard,
# Nearest to may: telo, mystique, schisms, catering, memorials, murr, truthful, unction,
# Nearest to used: naturalis, locally, dipped, skew, conclave, anticommunist, aviators, revolutions,
# Nearest to many: zionists, receptors, churchyard, ldl, hhs, fubar, stockhausen, elastic,
# Nearest to not: hitchens, heapsort, psychoactive, autonomic, affirms, meditative, walkie, abeda,
# Nearest to i: fawkes, supra, catalytic, debug, hitch, sociolinguistics, branden, lolita,
# Nearest to be: filter, bourgeoisie, saw, tapu, weather, fretless, near, tricyclic,
# Nearest to to: bitten, mancala, responses, mair, sentient, portraits, apicomplexa, beating,
# Nearest to been: riots, afterword, infiltration, penetrates, kosher, multiplan, relativism, digraph,
# Nearest to nine: antagonism, crewed, variety, sandals, streptococcus, edwin, contemporaneously, earliest,
# Nearest to only: eugenicists, winner, babur, tamburlaine, mondo, evergreen, chee, relinquish,
# Nearest to who: teacher, km, blackened, swimming, las, tapioca, kara, winners,
# Nearest to use: etat, inflation, cvd, blues, bostonians, nami, screen, uterine,
# Nearest to s: woolen, odense, pounded, manifolds, erasable, whaling, consecutively, reinhold,
# Average loss at step 2000: 4.357932
# Average loss at step 4000: 3.863890
# Average loss at step 6000: 3.789243
# Average loss at step 8000: 3.688720
# Average loss at step 10000: 3.611709
# Nearest to an: cauldron, tombs, chapel, waff, siona, enough, interrogations, alchemy,
# Nearest to called: benefits, contraceptives, lgbt, ringers, mysia, sadie, treason, inflationary,
# Nearest to d: mimeograph, b, handwriting, commandos, partake, sorghum, vma, redefine,
# Nearest to may: pavia, can, must, employers, should, memorials, truthful, schisms,
# Nearest to used: praising, bullying, alamo, poll, known, qasim, inadequate, iceberg,
# Nearest to many: some, tropical, tumor, receptors, dominica, schiller, prosecuted, reginald,
# Nearest to not: it, could, they, there, also, to, usually, heapsort,
# Nearest to i: hayden, supra, undertake, carrots, fawkes, angels, might, sociolinguistics,
# Nearest to be: have, bourgeoisie, been, refer, is, audi, soaked, runciman,
# Nearest to to: download, mair, not, mancala, encyclical, plurals, dosage, responses,
# Nearest to been: was, be, were, presbyterianism, packing, had, afterword, doughnuts,
# Nearest to nine: eight, five, seven, six, zero, three, four, two,
# Nearest to only: normalization, someone, dancers, mondo, detached, ilya, do, heavily,
# Nearest to who: jeannie, and, he, blackened, often, adages, betty, imitate,
# Nearest to use: bostonians, etat, caricatured, screen, twist, besson, offered, connected,
# Nearest to s: paradise, lvarez, his, melaka, seleucid, celtic, and, pounded,
# Average loss at step 12000: 3.602377
# Average loss at step 14000: 3.567065
# Average loss at step 16000: 3.403262
# Average loss at step 18000: 3.457160
# Average loss at step 20000: 3.539411
# Nearest to an: tombs, the, waff, interrogations, morpheus, secretions, siam, ackermann,
# Nearest to called: contraceptives, benefits, treason, inflationary, glimpses, mysia, sadie, known,
# Nearest to d: b, handwriting, commandos, american, depreciation, mimeograph, concisely, bohdan,
# Nearest to may: can, should, would, must, could, pavia, will, alfalfa,
# Nearest to used: known, considered, wingers, involved, unwelcome, cripps, purest, colspan,
# Nearest to many: some, these, several, other, all, tropical, schiller, those,
# Nearest to not: usually, also, to, it, they, too, deliriants, pitchers,
# Nearest to i: hayden, ii, supra, we, undertake, king, hughes, pore,
# Nearest to be: have, refer, been, by, bourgeoisie, were, was, become,
# Nearest to to: mancala, could, not, will, may, download, charcot, enclosing,
# Nearest to been: were, be, become, was, presbyterianism, by, packing, kato,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to only: normalization, someone, dancers, do, detached, spacesuit, whampoa, earliest,
# Nearest to who: he, which, often, they, jeannie, she, also, stoker,
# Nearest to use: bostonians, connected, offered, besson, etat, true, sera, satem,
# Nearest to s: icosidodecahedron, archtop, beltane, marshallese, celtic, seleucid, reuniting, pleistocene,
# Average loss at step 22000: 3.505432
# Average loss at step 24000: 3.485864
# Average loss at step 26000: 3.478192
# Average loss at step 28000: 3.480215
# Average loss at step 30000: 3.508455
# Nearest to an: tombs, airways, norsemen, waff, siona, interrogations, secretions, royale,
# Nearest to called: xinhua, supposing, illustrates, glimpses, wolf, treason, sadie, grub,
# Nearest to d: b, commandos, l, catering, dilution, shower, styne, handwriting,
# Nearest to may: can, would, must, should, will, could, pavia, might,
# Nearest to used: known, written, involved, considered, addition, wingers, difficult, purest,
# Nearest to many: some, several, these, those, all, schiller, most, various,
# Nearest to not: they, it, now, there, often, who, generally, favorites,
# Nearest to i: ii, we, hayden, supra, undertake, t, runoff, you,
# Nearest to be: refer, have, been, become, are, take, bourgeoisie, is,
# Nearest to to: mancala, will, can, could, would, download, plurals, must,
# Nearest to been: become, were, was, be, kato, packing, presbyterianism, adverbial,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to only: voyager, detached, ilya, dancers, start, grabbing, does, dardanelles,
# Nearest to who: he, which, they, jeannie, she, often, now, relics,
# Nearest to use: bostonians, type, sera, true, mysore, malleable, etat, variety,
# Nearest to s: his, reuniting, canyon, archtop, commodus, tenant, nitric, inquisitor,
# Average loss at step 32000: 3.496701
# Average loss at step 34000: 3.491879
# Average loss at step 36000: 3.454103
# Average loss at step 38000: 3.305425
# Average loss at step 40000: 3.425333
# Nearest to an: tombs, norsemen, interrogations, secretions, prosecutor, weierstrass, avenues, another,
# Nearest to called: xinhua, thatcherism, wolf, supposing, glimpses, known, murmur, styled,
# Nearest to d: b, UNK, l, commandos, kaddish, gecko, dilution, c,
# Nearest to may: can, must, would, will, should, could, might, pavia,
# Nearest to used: known, considered, available, found, referred, addition, written, held,
# Nearest to many: some, several, these, various, those, prosecuted, schiller, dreadful,
# Nearest to not: it, generally, they, often, now, still, only, deliriants,
# Nearest to i: we, ii, you, t, hayden, kare, undertake, they,
# Nearest to be: refer, have, been, become, is, metallurgical, are, uneasy,
# Nearest to to: will, could, download, can, may, mancala, must, cannot,
# Nearest to been: become, be, were, was, oahu, kato, symbolised, packing,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to only: detached, voyager, whampoa, not, start, ilya, it, polymath,
# Nearest to who: he, often, also, which, relics, jeannie, they, she,
# Nearest to use: sera, true, exist, type, bostonians, malleable, outlet, reunified,
# Nearest to s: his, xvi, canyon, sip, elliot, gorillas, inquirer, eucharist,
# Average loss at step 42000: 3.435188
# Average loss at step 44000: 3.446054
# Average loss at step 46000: 3.446385
# Average loss at step 48000: 3.360489
# Average loss at step 50000: 3.383007
# Nearest to an: another, secretions, interrogations, waff, tombs, norsemen, siona, weierstrass,
# Nearest to called: named, known, lgbt, xinhua, supposing, wolf, thatcherism, grub,
# Nearest to d: b, l, p, gecko, c, commandos, kaddish, r,
# Nearest to may: can, would, should, must, will, could, might, does,
# Nearest to used: known, available, considered, written, referred, difficult, involved, able,
# Nearest to many: some, several, these, various, those, other, most, dreadful,
# Nearest to not: generally, they, now, usually, awarded, often, never, almost,
# Nearest to i: we, ii, you, t, devito, outlived, hayden, kare,
# Nearest to be: refer, was, have, become, been, being, were, metallurgical,
# Nearest to to: mancala, would, could, honeydew, encyclical, through, exploitative, can,
# Nearest to been: become, were, be, was, kato, oahu, symbolised, being,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to only: earliest, does, start, inherently, rien, regatta, voyager, polymath,
# Nearest to who: he, which, she, also, they, there, relics, jeannie,
# Nearest to use: exist, sera, reunified, most, outlet, representatives, form, probability,
# Nearest to s: whose, rebus, and, ligase, archtop, brokers, reuniting, hath,
# Average loss at step 52000: 3.436078
# Average loss at step 54000: 3.430294
# Average loss at step 56000: 3.437297
# Average loss at step 58000: 3.394260
# Average loss at step 60000: 3.391322
# Nearest to an: interrogations, secretions, waff, tombs, another, noirs, cauldron, airways,
# Nearest to called: named, lgbt, known, used, traded, grub, brendan, xinhua,
# Nearest to d: b, l, r, c, p, kaddish, e, cante,
# Nearest to may: can, would, should, must, will, could, might, does,
# Nearest to used: known, considered, difficult, available, written, held, referred, designed,
# Nearest to many: some, several, various, these, those, most, other, numerous,
# Nearest to not: now, still, usually, there, generally, it, magnates, they,
# Nearest to i: we, ii, you, t, hayden, they, devito, undertake,
# Nearest to be: refer, been, become, being, was, is, metallurgical, bourgeoisie,
# Nearest to to: mancala, edged, ensured, oceans, and, would, only, holism,
# Nearest to been: become, be, kato, were, was, had, repeatedly, oahu,
# Nearest to nine: eight, seven, six, four, five, three, one, zero,
# Nearest to only: voyager, until, start, earliest, does, liebig, inherently, always,
# Nearest to who: he, which, she, now, also, jeannie, relics, never,
# Nearest to use: most, exist, outlet, cripps, form, puzzled, reunified, existed,
# Nearest to s: whose, ethnographic, adams, gorillas, toolbars, archtop, emi, brokers,
# Average loss at step 62000: 3.245002
# Average loss at step 64000: 3.257326
# Average loss at step 66000: 3.402760
# Average loss at step 68000: 3.389399
# Average loss at step 70000: 3.360981
# Nearest to an: interrogations, secretions, waff, siona, haereses, noirs, prosecutor, norsemen,
# Nearest to called: named, known, used, but, lgbt, traded, rot, staged,
# Nearest to d: b, l, r, commandos, wishful, dilution, p, gecko,
# Nearest to may: can, would, must, should, will, could, might, cannot,
# Nearest to used: known, available, written, considered, referred, addition, designed, involved,
# Nearest to many: some, several, various, these, most, those, such, all,
# Nearest to not: now, never, still, generally, usually, typically, almost, partially,
# Nearest to i: we, ii, you, unhappy, t, gnasher, g, they,
# Nearest to be: been, being, become, refer, were, is, are, have,
# Nearest to to: will, mancala, would, must, can, could, cannot, plurals,
# Nearest to been: become, be, was, were, repeatedly, fennel, recently, kato,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to only: voyager, still, employ, quinine, start, actually, until, either,
# Nearest to who: he, which, relics, now, they, she, never, overtures,
# Nearest to use: outlet, form, exist, most, scrooge, sense, reunified, representatives,
# Nearest to s: xvi, whose, rebus, reuniting, hath, must, boot, logistical,
# Average loss at step 72000: 3.369472
# Average loss at step 74000: 3.346847
# Average loss at step 76000: 3.313208
# Average loss at step 78000: 3.349800
# Average loss at step 80000: 3.379306
# Nearest to an: interrogations, weierstrass, waff, cauldron, secretions, siona, tombs, airways,
# Nearest to called: named, used, known, traded, lgbt, riggs, staged, wolf,
# Nearest to d: b, l, p, g, e, m, freiburg, r,
# Nearest to may: must, can, would, will, should, could, might, cannot,
# Nearest to used: known, available, referred, written, considered, found, called, classified,
# Nearest to many: some, several, various, these, numerous, few, those, most,
# Nearest to not: still, usually, now, never, they, generally, you, it,
# Nearest to i: we, ii, you, t, unhappy, g, sh, sir,
# Nearest to be: been, refer, being, become, have, were, remain, are,
# Nearest to to: mancala, mannerheim, would, will, ensured, enrollments, predate, encyclical,
# Nearest to been: become, be, was, fennel, were, recently, repeatedly, adverbial,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to only: voyager, first, until, premise, battling, finishing, either, inherently,
# Nearest to who: he, which, they, jeannie, she, relics, ever, never,
# Nearest to use: puzzled, exist, malleable, mare, reunified, side, outlet, type,
# Nearest to s: xvi, sanj, emi, isbn, rebus, derail, archtop, elliot,
# Average loss at step 82000: 3.406782
# Average loss at step 84000: 3.410512
# Average loss at step 86000: 3.387329
# Average loss at step 88000: 3.353400
# Average loss at step 90000: 3.363613
# Nearest to an: interrogations, waff, robb, secretions, norsemen, siona, another, frankel,
# Nearest to called: used, named, known, considered, referred, xinhua, unwelcome, thatcherism,
# Nearest to d: b, depreciation, l, freiburg, r, t, adele, p,
# Nearest to may: can, must, would, should, could, might, will, cannot,
# Nearest to used: known, referred, available, called, considered, designed, found, described,
# Nearest to many: several, some, various, these, numerous, most, all, those,
# Nearest to not: still, now, nor, never, generally, magnates, partially, they,
# Nearest to i: we, ii, you, g, sh, t, iii, unhappy,
# Nearest to be: been, become, being, refer, was, have, is, remain,
# Nearest to to: mancala, would, will, mair, charcot, enrollments, almagro, biggest,
# Nearest to been: become, be, was, already, were, repeatedly, recently, fennel,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to only: voyager, premise, either, until, no, actually, inherently, always,
# Nearest to who: he, which, often, they, actually, already, also, blackened,
# Nearest to use: representatives, document, exist, side, list, puritans, puzzled, aotearoa,
# Nearest to s: rebus, whose, jennie, xvi, isbn, archtop, unabated, sharm,
# Average loss at step 92000: 3.401841
# Average loss at step 94000: 3.247775
# Average loss at step 96000: 3.355931
# Average loss at step 98000: 3.238953
# Average loss at step 100000: 3.357533
# Nearest to an: interrogations, another, tombs, morpheus, secretions, waff, siona, cauldron,
# Nearest to called: named, known, used, riggs, referred, augusta, unwelcome, xinhua,
# Nearest to d: b, freiburg, tat, c, l, r, rotor, mathrm,
# Nearest to may: can, should, could, must, might, would, will, cannot,
# Nearest to used: referred, known, considered, available, designed, found, described, called,
# Nearest to many: several, some, these, various, numerous, few, those, all,
# Nearest to not: almost, never, they, now, still, partially, generally, nor,
# Nearest to i: we, you, ii, unhappy, t, voris, kare, they,
# Nearest to be: been, refer, become, have, are, being, remain, were,
# Nearest to to: will, could, would, should, must, mancala, can, and,
# Nearest to been: become, be, already, recently, were, repeatedly, was, kato,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to only: until, voyager, battling, gage, either, actually, inherently, earliest,
# Nearest to who: he, actually, and, ever, never, also, she, jeannie,
# Nearest to use: outlet, representatives, most, form, gemara, peril, sense, puritans,
# Nearest to s: whose, his, rebus, xvi, my, your, sanj, inquisitor,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
